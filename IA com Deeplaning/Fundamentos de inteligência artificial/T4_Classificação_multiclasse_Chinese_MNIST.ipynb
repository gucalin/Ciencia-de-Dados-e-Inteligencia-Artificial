# %% [markdown]
# # Trabalho #4 - Classificação multiclasse
#
# Nesse trabalho você vai treinar uma rede para realizar uma tarefa de classificação multiclasse.
#
# A tarefa é classificar imagens de dígitos numéricos chineses.

# %% [markdown]
# ## Coloque seu nome aqui:
#
# Aluno:

# %% [markdown]
# ### Importação das principais bibliotecas
#
# Em primeiro lugar é necessário importar alguns pacotes do Python que serão usados nesse trabalho.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import os

# %% [markdown]
# ## 1 - Visão geral do problema
#
# O objetivo desse problema é determinar o dígito da lingua chinesa que é mostrado em uma imagem usando uma RNA. Assim, esse problema consiste em dada uma imagem, a RNA avalia a probabilidade de existirem determinados dígitos na imagem e determina qual o mais provável entre 15 possíveis.
#
# O banco de dados usado nesse exemplo é o Chinese-MNIST, que consiste de imagens de dígitos chineses. Esse banco de dados pode ser obtido no Kaggle em https://www.kaggle.com/gpreda/chinese-mnist.

# %% [markdown]
# ## 2 - Dados de treinamento
#
# Características dos dados:
#
# - O banco de dados Chinese MNIST possui 15.000 exemplos;
# - Cada exemplo consiste de uma imagem em tons de cinza, de dimensão 64x64 pixels;
# - Cada imagem é associada a um rótulo de 15 classes;
# - O valor da intensidade luminosa de cada pixel da imagem é um número inteiro entre 0 e 255.
#
# Primeiramente você deve acessar o link do Kaggle onde se encontra os dados e fazer download dos mesmos e descompactar o arquivo.
#
#
# ### 2.1 Carregar dados
#
# Após descompactar o arquivo com os dados execute as células abaixo para carregar e inspecionar os dados.
#
# Note que os dados devem estar em uma pasta de nome `Chinese_MNIST` e as imagens estão dentro da pasta `Chinese_MNIST/data`.
#
# O arquivo `chinese_mnist.csv` contém os nomes dos arquivos das imagens codificados e as classes de cada imagem.

# %%
# Carrega arquivo de informações sobre dados
data_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Ciência de Dados e Inteligência Artificial/IA com Deeplaning/Fundamentos de inteligência artificial/chinese_mnist.csv')
data_df.head()
# Out:
#    suite_id  sample_id  code  value character
# 0         1          1    10      9         九
# 1         1         10    10      9         九
# 2         1          2    10      9         九
# 3         1          3    10      9         九
# 4         1          4    10      9         九

# %% [markdown]
# ### 2.2 Inspecionar dados
#
# Vamos verificar o número de dados de cada classe de dígito, se existem dados ausentes e quantos arquivos de imagens existem.

# %%
data_df.groupby(["value","character"]).size()
# Out:
# value      character
# 0          零            1000
# 1          一            1000
# 2          二            1000
# 3          三            1000
# 4          四            1000
# 5          五            1000
# 6          六            1000
# 7          七            1000
# 8          八            1000
# 9          九            1000
# 10         十            1000
# 100        百            1000
# 1000       千            1000
# 10000      万            1000
# 100000000  亿            1000
# dtype: int64

# %%
# Verifica se existem dados ausentes
total = data_df.isnull().sum().sort_values(ascending = False)
percent = (data_df.isnull().sum()/data_df.isnull().count()*100).sort_values(ascending = False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#            Total  Percent
# suite_id       0      0.0
# sample_id      0      0.0
# code           0      0.0
# value          0      0.0
# character      0      0.0

# %%
# Verifica número de arquivos de imagens existentes
image_files = list(os.listdir("/content/drive/MyDrive/Colab Notebooks/Ciência de Dados e Inteligência Artificial/IA com Deeplaning/Fundamentos de inteligência artificial/data"))
print("Numero de imagens: {}".format(len(image_files)))
# Out:
# Numero de imagens: 15000

# %% [markdown]
# ### 2.3 Anexar propriedades das imagens ao dataframe
#
# Como as imagens tem uma convenção de nome de `input_ [siote_id] _ [sample_id] _ [código] .jpg`, devemos criar mais uma coluna no dataframe com o nome do arquivo das imagens para podermos associar cada imagem à sua classe correspondente.

# %%
import skimage.io

def image_files(x):
    file_name = f"input_{x[0]}_{x[1]}_{x[2]}.jpg"
    return file_name
data_df["file"] = data_df.apply(image_files, axis=1)

def image_sizes(file_name):
    image = skimage.io.imread("Chinese_MNIST/data/" + file_name)
    return list(image.shape)

data_df = pd.concat([data_df],axis=1, sort=False)

data_df.head()
# Out:
# /tmp/ipython-input-1107830529.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   file_name = f"input_{x[0]}_{x[1]}_{x[2]}.jpg"
#    suite_id  sample_id  code  value character               file
# 0         1          1    10      9         九   input_1_1_10.jpg
# 1         1         10    10      9         九  input_1_10_10.jpg
# 2         1          2    10      9         九   input_1_2_10.jpg
# 3         1          3    10      9         九   input_1_3_10.jpg
# 4         1          4    10      9         九   input_1_4_10.jpg

# %% [markdown]
# ## 3. Processamento dos dados
#
# Primeiramente precisamos dividir os dados nos conjuntos de treinamento e teste. Vamos usar 80% para treinamento e 20% para teste/validação.

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(data_df, test_size=0.2, random_state=42, stratify=data_df["code"].values)

print("Train set: {}".format(train_df.shape))
print("Test set: {}".format(test_df.shape))
# Out:
# Train set: (12000, 6)
# Test set: (3000, 6)

# %% [markdown]
# As imagens precisam ser carregadas, redimensionadas e normalizadas. Para isso vamos usar uma função que carrega as imagens, redimensiona-as para (64, 64) e normaliza os pixels para terem valores reais entre 0 e 1.
#
# Precisamos também de uma função para criar a classe do dígito correspondente a cada imagem.

# %%
import skimage.transform

def read_image(file_name):
    #print(file_name)
    image = skimage.io.imread("/content/drive/MyDrive/Colab Notebooks/Ciência de Dados e Inteligência Artificial/IA com Deeplaning/Fundamentos de inteligência artificial/data/" + file_name)
    image = skimage.transform.resize(image, (64, 64), mode='reflect')
    return image

def categories_encoder(dataset, var='character'):
    X = np.stack(dataset['file'].apply(read_image))
    y = pd.get_dummies(dataset[var], drop_first=False)
    return X, y

X_train, y_train = categories_encoder(train_df)
X_test, y_test = categories_encoder(test_df)

print('Dimensão do tensor das imagens de treinamento:', X_train.shape)
print('Dimensão do tensor das imagens de teste:', X_test.shape)
print('Dimensão do tensor de classes de treinamento:', y_train.shape)
print('Dimensão do tensor de classes de teste:', y_test.shape)
# Out:
# Dimensão do tensor das imagens de treinamento: (12000, 64, 64)
# Dimensão do tensor das imagens de teste: (3000, 64, 64)
# Dimensão do tensor de classes de treinamento: (12000, 15)
# Dimensão do tensor de classes de teste: (3000, 15)

# %% [markdown]
# Como vamos processar as imagens com uma rede de camadas densas, devemos transformá-las em vetores.

# %%
# Redimensionamento das images
X_train_flat = np.reshape(X_train, (12000, 64*64))
X_test_flat = np.reshape(X_test, (3000, 64*64))

# Transformação das saídas em tensor numpy
y_train = np.array(y_train)
y_test = np.array(y_test)

print('Dimensão do tensor das imagens de treinamento:', X_train_flat.shape)
print('Dimensão do tensor das imagens de teste:', X_test_flat.shape)
print('Dimensão do tensor de classes de treinamento:', y_train.shape)
print('Dimensão do tensor de classes de teste:', y_test.shape)
print('Valores mímnimo e máximo dos pixels das imagens:', np.min(X_train_flat), np.max(X_train_flat))
# Out:
# Dimensão do tensor das imagens de treinamento: (12000, 4096)
# Dimensão do tensor das imagens de teste: (3000, 4096)
# Dimensão do tensor de classes de treinamento: (12000, 15)
# Dimensão do tensor de classes de teste: (3000, 15)
# Valores mímnimo e máximo dos pixels das imagens: 0.0 1.0

# %%
# Exemplo de uma imagem
index = 11
plt.imshow(X_train[index], cmap='gray')
print ("y = " + str(np.argmax(y_train[index])) + " (y_hot=" + str(y_train[index]) + ")")
# Out:
# y = 4 (y_hot=[False False False False  True False False False False False False False
#  False False False])

# %% [markdown]
# ## 3. Para você fazer
#
# Você deve desenvolver uma rede neural usando a plataforma TensorFlow-Keras, para classificar os dígitos escritos em chinês.
#
# Além de mostrar a configuração da rede utilizada, os parâmetros escolhidos para a compilação e treinamento, apresente pelo menos os seguintes resultados:
#
# 1. Resultado do processo de treinamento (gráficos);
#
# 2. Valores da função de custo e da métrica para os dados de treinamento e teste (use o método evaluate);
#
# 3. Gráfico com as classes previstas junto com as classes reais dos dados de teste. Use círculos de cores diferentes para diferenciar as classe previstas das reais.
#
# 4. Matriz de confusão dos resulatdos para facilitar a análise de desempenho da sua rede.
#
# Para entregar o seu trabalho, transforme o seu notebook em pdf e faça o upload do mesmo nesse espaço.

# %%
# Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train_flat.shape[1],)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(y_train.shape[1], activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       524,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 15)             │           975 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 533,647 (2.04 MB)
#  Trainable params: 533,647 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train_flat, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.2174 - loss: 2.4165 - val_accuracy: 0.5288 - val_loss: 1.5903
# Epoch 2/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5497 - loss: 1.4381 - val_accuracy: 0.6546 - val_loss: 1.1361
# Epoch 3/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6789 - loss: 1.0049 - val_accuracy: 0.6954 - val_loss: 0.9482
# Epoch 4/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7465 - loss: 0.7670 - val_accuracy: 0.7283 - val_loss: 0.8360
# Epoch 5/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7860 - loss: 0.6512 - val_accuracy: 0.7462 - val_loss: 0.7733
# Epoch 6/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8143 - loss: 0.5629 - val_accuracy: 0.7550 - val_loss: 0.7564
# Epoch 7/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8386 - loss: 0.4818 - val_accuracy: 0.7683 - val_loss: 0.7250
# Epoch 8/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8531 - loss: 0.4269 - val_accuracy: 0.7671 - val_loss: 0.7122
# Epoch 9/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8676 - loss: 0.3815 - val_accuracy: 0.7667 - val_loss: 0.7429
# Epoch 10/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8810 - loss: 0.3400 - val_accuracy: 0.7713 - val_loss: 0.7310
# Epoch 11/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8976 - loss: 0.3009 - val_accuracy: 0.7771 - val_loss: 0.7403
# Epoch 12/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9108 - loss: 0.2652 - val_accuracy: 0.7883 - val_loss: 0.7283
# Epoch 13/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9126 - loss: 0.2601 - val_accuracy: 0.7742 - val_loss: 0.7606
# Epoch 14/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9247 - loss: 0.2300 - val_accuracy: 0.7858 - val_loss: 0.7433
# Epoch 15/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9311 - loss: 0.2113 - val_accuracy: 0.7862 - val_loss: 0.7664
# Epoch 16/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9286 - loss: 0.2046 - val_accuracy: 0.7850 - val_loss: 0.7876
# Epoch 17/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9357 - loss: 0.1838 - val_accuracy: 0.7887 - val_loss: 0.7898
# Epoch 18/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9331 - loss: 0.1905 - val_accuracy: 0.7854 - val_loss: 0.7897
# Epoch 19/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9391 - loss: 0.1741 - val_accuracy: 0.7862 - val_loss: 0.8326
# Epoch 20/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9456 - loss: 0.1577 - val_accuracy: 0.7883 - val_loss: 0.8251
# Epoch 21/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9455 - loss: 0.1539 - val_accuracy: 0.7912 - val_loss: 0.8510
# Epoch 22/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9554 - loss: 0.1395 - val_accuracy: 0.7912 - val_loss: 0.8910
# Epoch 23/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9555 - loss: 0.1351 - val_accuracy: 0.7808 - val_loss: 0.9139
# Epoch 24/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9580 - loss: 0.1411 - val_accuracy: 0.7971 - val_loss: 0.8907
# Epoch 25/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9643 - loss: 0.1185 - val_accuracy: 0.7950 - val_loss: 0.8832
# Epoch 26/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9591 - loss: 0.1231 - val_accuracy: 0.7800 - val_loss: 0.9468
# Epoch 27/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9586 - loss: 0.1198 - val_accuracy: 0.7833 - val_loss: 0.9582
# Epoch 28/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9616 - loss: 0.1168 - val_accuracy: 0.7875 - val_loss: 0.9197
# Epoch 29/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9649 - loss: 0.1052 - val_accuracy: 0.7846 - val_loss: 1.0135
# Epoch 30/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9692 - loss: 0.0923 - val_accuracy: 0.7850 - val_loss: 1.0285
# Epoch 31/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9691 - loss: 0.0900 - val_accuracy: 0.7850 - val_loss: 1.0109
# Epoch 32/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9697 - loss: 0.0951 - val_accuracy: 0.7708 - val_loss: 1.0516
# Epoch 33/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9688 - loss: 0.0943 - val_accuracy: 0.7867 - val_loss: 1.0563
# Epoch 34/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9681 - loss: 0.0927 - val_accuracy: 0.7758 - val_loss: 1.1161
# Epoch 35/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9674 - loss: 0.1007 - val_accuracy: 0.7837 - val_loss: 1.0436
# Epoch 36/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9672 - loss: 0.0966 - val_accuracy: 0.7892 - val_loss: 1.0362
# Epoch 37/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9720 - loss: 0.0877 - val_accuracy: 0.7871 - val_loss: 1.0715
# Epoch 38/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9775 - loss: 0.0704 - val_accuracy: 0.7850 - val_loss: 1.0866
# Epoch 39/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9747 - loss: 0.0748 - val_accuracy: 0.7833 - val_loss: 1.0576
# Epoch 40/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9733 - loss: 0.0775 - val_accuracy: 0.7833 - val_loss: 1.0678
# Epoch 41/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9759 - loss: 0.0716 - val_accuracy: 0.7821 - val_loss: 1.1273
# Epoch 42/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9748 - loss: 0.0780 - val_accuracy: 0.7808 - val_loss: 1.1345
# Epoch 43/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9730 - loss: 0.0758 - val_accuracy: 0.7746 - val_loss: 1.1711
# Epoch 44/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9736 - loss: 0.0789 - val_accuracy: 0.7767 - val_loss: 1.1625
# Epoch 45/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9773 - loss: 0.0698 - val_accuracy: 0.7758 - val_loss: 1.2205
# Epoch 46/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9764 - loss: 0.0754 - val_accuracy: 0.7775 - val_loss: 1.1744
# Epoch 47/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9800 - loss: 0.0624 - val_accuracy: 0.7746 - val_loss: 1.2271
# Epoch 48/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9770 - loss: 0.0667 - val_accuracy: 0.7817 - val_loss: 1.1707
# Epoch 49/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9767 - loss: 0.0715 - val_accuracy: 0.7817 - val_loss: 1.1990
# Epoch 50/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9791 - loss: 0.0649 - val_accuracy: 0.7733 - val_loss: 1.2426

# %%
# Salva treinamento na variável history para visualização
history_dict = history.history

# Salva custos, métricas e epocas em vetores
custo = history_dict['loss']
acc = history_dict['accuracy']
val_custo = history_dict['val_loss']
val_acc = history_dict['val_accuracy']

# Cria vetor de épocas
epocas = range(1, len(custo) + 1)

# Gráfico dos valores de custo
plt.plot(epocas, custo, 'bo', label='Custo - treinamento')
plt.plot(epocas, val_custo, 'r', label='Custo - validação')
plt.title('Valor da função de custo – treinamento e validação')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.legend()
plt.show()

# Gráfico dos valores da métrica
plt.plot(epocas, acc, 'bo', label='exatidao- treinamento')
plt.plot(epocas, val_acc, 'r', label='exatidao - validação')
plt.title('Valor da métrica – treinamento e validação')
plt.xlabel('Épocas')
plt.ylabel('Exatidao')
plt.legend()
plt.show()

# %%
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7992 - loss: 1.1345
# Loss on test data: 1.1229641437530518
# Accuracy on test data: 0.8036666512489319

# %%
# Resultado gráfico
# Verifique dimensoes dos vetores de classes reais e previstas
print('Dimensão vetor classes reais= ', y_true_classes.shape)
print('Dimensão vetor classes previstas= ', y_pred_classes.shape)

# Fazer o gráfico das classes reais e previstas
plt.figure(figsize=(18, 6))
plt.plot(y_true_classes[:100], 'bo', label='Classes reais')
plt.plot(y_pred_classes[:100], 'ro', label="Classes previstas")
plt.title('Classes reais e previstas')
plt.xlabel('Exemplos')
plt.ylabel('Classes')
plt.legend()
plt.show()
# Out:
# Dimensão vetor classes reais=  (3000,)
# Dimensão vetor classes previstas=  (3000,)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Get the unique characters for labeling the matrix
unique_characters = data_df['character'].unique()
unique_characters.sort()

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_characters, yticklabels=unique_characters)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 19971 (\N{CJK UNIFIED IDEOGRAPH-4E03}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 19975 (\N{CJK UNIFIED IDEOGRAPH-4E07}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20061 (\N{CJK UNIFIED IDEOGRAPH-4E5D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20116 (\N{CJK UNIFIED IDEOGRAPH-4E94}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20159 (\N{CJK UNIFIED IDEOGRAPH-4EBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20843 (\N{CJK UNIFIED IDEOGRAPH-516B}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21313 (\N{CJK UNIFIED IDEOGRAPH-5341}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 21315 (\N{CJK UNIFIED IDEOGRAPH-5343}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 22235 (\N{CJK UNIFIED IDEOGRAPH-56DB}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 38646 (\N{CJK UNIFIED IDEOGRAPH-96F6}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19971 (\N{CJK UNIFIED IDEOGRAPH-4E03}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19975 (\N{CJK UNIFIED IDEOGRAPH-4E07}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 19977 (\N{CJK UNIFIED IDEOGRAPH-4E09}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20061 (\N{CJK UNIFIED IDEOGRAPH-4E5D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20116 (\N{CJK UNIFIED IDEOGRAPH-4E94}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20159 (\N{CJK UNIFIED IDEOGRAPH-4EBF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20843 (\N{CJK UNIFIED IDEOGRAPH-516B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20845 (\N{CJK UNIFIED IDEOGRAPH-516D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21313 (\N{CJK UNIFIED IDEOGRAPH-5341}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21315 (\N{CJK UNIFIED IDEOGRAPH-5343}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22235 (\N{CJK UNIFIED IDEOGRAPH-56DB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38646 (\N{CJK UNIFIED IDEOGRAPH-96F6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

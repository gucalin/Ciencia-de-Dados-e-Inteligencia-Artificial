# %% [markdown]
# # Aula 7
#
# # Ferramentas de desenvolvimento
#
# ### Eduardo Lobo Lustosa Cabral

# %% [markdown]
# ## 1. Objetivos
#
# Comparar algumas ferramentas de desenvolvimento de RNAs.
#
# Introduzir a ferramenta de desenvolvimento Keras.
#
# Iniciar o desenvolvimento de soluções de problemas reais usando RNAs profundas com a ferramenta de desenvolvimento Keras.
#
# Desenvolvimento de RNAs com modelo sequencial usando o Keras.

# %% [markdown]
# ## 2. Ferramentas de desenvolvimento
#
#
# Praticamente ninguém desenvolve o seu próprio código para implementar e treinar uma RNA $\to$ existem inúmeras ferramentas de desenvolvimento, já testadas, que realizam a maior parte desse trabalho e que são amplamente utilizadas.
#
# A grande vantagem de utilizar uma dessas ferramentas advém do fato que somente precisamos definir a configuração da RNA, ou seja, definir as operações que a RNA realiza nos dados de entrada para prever as saídas, ou seja, precisamos somente definir como é realizada a propagação para frente.
#
# Nessas ferramentas ao definirmos a propagação para frente, fazendo uso de manipulação simbólica são gerados automaticamente os cálculos da retro-propagação, que é de fato a parte mais difícil da codificação de uma RNA.
#
# As ferramentas mais utilizadas de deep-learning atualmente são as seguintes:
#
# - TensorFlow;
# - Keras;
# - Pytorch;
# - ONNX;
# - Jax;
# - Outras.
#
# Todas essas ferramentas são de uso livre e estão disponíveis na internet.

# %% [markdown]
# ### 2.1 Comparação TensorFlow versus Pytorch
#
# TensorFlow (do Google) e PyTorch (da Meta AI) são as duas ferramentas  de deep learning mais dominantes em 2025.
#
# Ambos oferecem ferramentas para projetar, treinar e implantar redes neurais.
#
# A seguir alguns aspectos de ambas ferramanetas segundo ALALAWI, Zakariya Ba. A Comparative Survey of PyTorch vs TensorFlow for Deep Learning: Usability, Performance, and Deployment Trade offs. arXiv, 6 ago. 2025. Disponível em: arXiv:2508.04035. Acesso em: 26 ago. 2025.(https://leapcell.io/blog/tensorflow-vs-pytorch-a-comparative-analysis-for-2025?utm_source=chatgpt.com).
#
# **Pesquisa vs produção**
#
# * PyTorch domina na pesquisa acadêmica, sendo usado em cerca de 80% dos artigos sobre deep learning.
# * TensorFlow mantém presença forte em ambientes de produção, devido ao seu ecossistema de deploy (como o TensorFlow Serving, TFLite, TFX) e à eficiência na execução.
#
# **Desempenho & eficiência de recursos**
#
# * Velocidade de Treinamento: em modelos menores, PyTorch frequentemente treina mais rápido. Já em modelos maiores e com execução prolongada, o TensorFlow oferece melhor aproveitamento de GPU e maior eficiência.
#
# **Consumo de recursos**
#
# * Alguns estudos indicam que, em inferência em CPU, TensorFlow é mais eficiente do que PyTorch.
#
# **Ecossistema & ferramentas**
#
# * TensorFlow: possui ferramentas focadas na produção — como *TensorBoard* (visualização), *TensorFlow Serving*, *TensorFlow Lite* (mobile).
# * PyTorch: tem forte integração com ONNX (para compatibilidade entre frameworks) e *TorchScript* (para implantação em produção).
#
# **Comunidade & tendências de adoção**
#
# * PyTorch lidera na comunidade de pesquisa, especialmente nos EUA e Europa, com crescente adoção em produção ao longo de 2025.
# * TensorFlow mantém firme presença no uso empresarial, especialmente em aplicações de produção em larga escala, dispositivos móveis e edge.
#
#
# **Curva de aprendizado**
#
# * **PyTorch é mais fácil de aprender** para quem já conhece Python e computação científica.
# * **TensorFlow** exige familiaridade com seu ecossistema mais amplo, no entanto, o Keras integrado ao TensorFlow oferece um início mais amigável.
#
#
# **Utilização mais comum**
#
# | Caso de uso                                   | Ferramenta recomendada         |
# | --------------------------------------------- | ----------------------------- |
# | Pesquisa & prototipagem                       | **PyTorch**                   |
# | Produção em larga escala (mobile, enterprise) | **TensorFlow**                |
# | Compatibilidade entre frameworks              | **Ambos** (via ONNX ou Keras) |
# | Aprender fundamentos de IA                    | **Keras**      |
#
#
# Na Figura 1 é apresentada a adoção do uso do TensorFlow e do Pytorch em publicações da área acadêmica e na área empresarial.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Figura 1 - Uso das ferramentas TensorFlow e Pytorch (https://www.marketingscoop.com/tech/pytorch-vs-tensorflow-comprehensive-comparison-of-the-top-deep-learning-frameworks/?utm_source=chatgpt.com)

# %% [markdown]
# ### 2.2 Jax
#
# Jax é similar à bibloteca Numpy.
#
# O JAX apresenta um alto desempenho computacional, pricipalmente para operações de tensores.
#
# O JAX supera tanto o TensorFlow  como Pytorch, sendo cerca de 2 vezes mais rápido e usa cerca de 30% menos memória.
#
# O maior problema do Jax é ser mais difícil de usar, a curva de apredizado é mais demorada.
#
# Ressalta-se que todas essas 3 ferramentas se tornam simples se forem usadas como Backend do Keras.
#
#
# Tabela comparativa de uso (https://www.devbookmarks.com/p/pytorch-answer-comparison-pytorch-jax-tensorflow?utm_source=chatgpt.com
#
# | Cenário                          | JAX                                         | PyTorch                             | TensorFlow                               |
# | -------------------------------- | ------------------------------------------- | ----------------------------------- | ---------------------------------------- |
# | Pesquisa científica / HPC        | Ideal – rápido, funcional, baixas latências | Boa prototipagem e pesquisa         | Bom para protótipos e produção           |
# | Prototipagem rápida              | Pouco intuitivo, curva de aprendizado       | Mais simples e Pythonic             | Muito simples com o Keras   |
# | Produção / Deploy                | Precisa de esforço adicional                | Melhor com TorchServe / TorchScript | Ecossistema robusto (TFX, Lite, Serving) |
# | Operações matemáticas intensivas | Excelente (XLA, JIT, memória eficiente)     | Bom, mas menos eficiente que JAX    | Eficiente com configuração apropriada    |

# %% [markdown]
# ### 2.3 Keras
#
# O Keras é as ferramenta mais simples de usar para desenvolver novas aplicações de RNA $\to$ por essa razão nessa disciplina usaremos principalmente o Keras com Backend do TensorFlow.
#
# O Keras consiste de fato em somente uma interface mais amigável para outras ferramentas.
#
# **O Keras pode ser usado com o TensorFlow, Pytorch e Jax.**
#
# Ressalta-se que em razão da popularidade e da facilidade de uso do Keras, o TensorFlow (a partir da versão 1.13) incorpou o Keras $\to$ assim, atualmente existe a possibilidade de usar o Keras do TensorFlow.
#
# Deve-se ter cuidado com as inúmeras versões do TensorFlow e do Keras, porque um programa feito para uma versão mais antiga pode não funcionar com uma versão mais nova.
#
# É possível fazer praticamente qualquer tarefa na área de IA usando o Keras, somente algumas coisas mais complexas exige o uso de outras ferramentas.

# %% [markdown]
# ## 3. Introdução ao Keras
#
#
# O keras é uma ferramenta para desenvolvimento de RNAs deep-learning, baseado na linguagem Python, que fornece uma forma simples e conveniente de construir, treinar e testar uma RNA.
#
# A estrutura fundamental das RNAs são as camadas, que recebem como dado de entrada um tensor e geram como saída outro tensor.
#
# Existem diversos tipos de camadas, sendo que cada tipo é especifica para um determinado formato de tensor e para um determinado tipo de processamento. Assim, por exemplo:
#
# - Dados na forma de vetores são armazenados em tensores 2D (1º eixo: exemplos; 2º eixo: características) e processados tipicamente em camadas densamente conectadas, chamadas de camadas densas;
#
#
# - Dados de imagens tons de cinza são armazenados em tensores 3D (1º eixo: exemplos; 2º eixo: altura; 3º eixo: largura) e processadas tipicamente em camadas convolutivas;
#
#
# - Seqüências de dados temporais são armazenadas em tensores 3D (1º eixo: exemplos; 2º eixo: tempo; 3º eixo: características) e processados tipicamente em camadas recorrentes, por exemplo, camadas LSTM ou GRU.
#
# Como visto na Aula 6, as camadas podem ser vistas como sendo blocos que utilizamos para construir uma RNA.
#
# A construção de uma RNA usando o Keras é feita juntando camadas compatíveis para formar um processo de transformação de dados.
#
# A compatibilidade de uma camada com as outras consiste no fato de que cada camada somente aceita como entrada um tensor de um dado formato e gera na sua saída outro tensor de um determinado formato.
#
# No Keras existem duas formas de definir uma RNA:
#
# - Usando a classe Sequencial, que serve para definir RNAs com uma única sequência de camadas, que é o tipo mais comum de RNAs;
#
#
# -  Usando a classe Funcional, que serve para configurar modelos que possuem sequência de camadas cíclicas ou em árvore, essa forma permite configurar RNAs com arquiteturas totalmente arbitrárias.
# </span>
#
# Começaremos com a forma mais simples de criar uma RNA no Keras $\to$ que são os modelos sequenciais.
#
# A documentação do Keras fornece detalhes sobre a sua utilização. Essa documentação pode ser vista no link https://keras.io/
#
# O manual do Keras do TensorFlow está disponível no link https://www.tensorflow.org/api_docs/python/tf/keras.
#
#
# #### Etapas de desenvolvimento de uma RNA com o Keras
#
# A criação, treinamento e teste de uma RNA com o Keras é feito nas seguintes etapas:
#
# 1. Definição dos dados de treinamento e de teste;
#
#
# 2. Configuração da RNA, que consiste na definição das camadas da RNA para realizar o mapeamento das entradas nas saídas desejadas;
#
#
# 3. Compilação da RNA, que também inclui a configuração do processo de treinamento pela escolha da função de custo, do otimizador e da métrica para avaliar o desempenho;
#
#
# 4. Treinamento da RNA;
#
#
# 5. Teste e avaliação do desempenho da RNA.

# %% [markdown]
# ## 4. Dados de treinamento
#
# Nessa etapa os dados de treinamento e teste são organizados em tensores.
#
# A forma como os dados são organizados depende do tipo de dados $\to$ veremos diversos exemplos ao longo da disciplina.
#
# <br>
# <span style="color:red">
# Formato esperado dos dados no Keras $\to$ o Keras espera que o primeiro eixo dos dados, tanto de entrada, como de saída da RNA seja o número de exemplos. CUIDADO: esse formato é diferente do que vimos nas aulas anteriores.
# </span>
#
# Por exemplo $\to$ em um problema de classificação binária onde os dados de entrada de cada exemplo é um vetor com $n_{x}$ elementos, a saída é um escalar e existem $m$ exemplos, então os tensores de entrada e de saída da RNA esperado pelo Keras são os seguintes:
#
# - Dimensão do tensor de entrada $\to$ $(m, n_{x})$, ou seja, nesse caso temos que transpor os vetores de entrada para transformá-los em vetores linha, de forma que quando colocados juntos em  uma matriz, cada linha corresponde à entrada de um exemplo;
#
#
# - Dimensão do tensor de saída $\to$ $(m, 1)$, ou seja, o vetor com as saídas é um vetor coluna, onde cada elemento é a saída esperada de um exemplo.

# %% [markdown]
# ## 5. Configuração da RNA
#
# A estrutura de dados de uma RNA no Keras é chamada de modelo $\to$ um modelo é uma instância que organiza as camadas da RNA.
#
# Um modelo seqüencial, ou RNA seqüencial, consiste de um empilhamento de camadas.
#
# **Keras com TensorFlow**
#
# Antes de poder usar o Keras temos primeiramente que importar para o nosso ambiente de programação o Keras. Isso pode ser feito das seguintes formas:
#
# 1. Importando o Keras do TensorFlow (melhor forma)
#
#         import tensorflow as tf
#         tf.__version__
#
# 2. Importanto o Keras com Backend do TensorFlow
#
#         import os
#         os.environ["KERAS_BACKEND"] = "tensorflow"
#         import keras
#         print(keras.backend.backend())  # Deve retornar: 'tensorflow'
#
#
# **Keras com Pytorch**
#
# No caso de se usar o Keras com o Pytorch temos que primeiramente instalar algumas bibliotecas:
#
#         !pip install keras-core
#         !pip install torch
#
# Depois realizar as importações:
#
#         import os
#         os.environ["KERAS_BACKEND"] = "torch"
#         import keras_core as keras
#         print(keras.backend.backend())  # Deve retornar: 'torch'
#
#
# Como vamos usar o Keras do TensorFlow vamos fazer da forma mais eficiente.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.19.0'

# %% [markdown]
# - O comando `tf __version__` fornece a informação de qual versão do TensorFlow estamos usando.

# %% [markdown]
# Após importar o TensorFlow podemos importar as funções do Keras que queremos usar da seguinte forma:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %% [markdown]
# - Esses dois comandos importam a estrutura de modelo seqüencial e as camadas do tipo totalmente conectadas (densa) e as funções de ativação.

# %% [markdown]
# Uma RNA sequencial pode ser criada simplesmente passando uma lista de instâncias de camadas para o construtor do Keras, da seguinte forma:

# %%
model = Sequential([
    Dense(32,input_shape=(100,)),
    Activation('relu'),
    Dense(1),
    Activation('sigmoid')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# ...

# %% [markdown]
# - Esse comando define uma RNA de uma camada intermediária e uma camada de saída com as seguintes características:
#
#    * Os dados de entrada de cada exemplo de treinamento são vetores linha de dimensão (1024);
#    * Observa-se que não é incluída a dimensão do segundo eixo do tensor de entrada no argumento `input_shape`, porque nesse momento não se conhece o número de exemplos que serão usados no treinamento;
#    * Cuidado $\to$ apesar de parecer que no argumento `input_shape` o segundo eixo é o número de exemplos, o Keras espera que o primeiro eixo do tensor de entrada seja o número de exemplos;
#    * A camada escondida é do tipo densa (totalmente conectada), possui 32 neurônios e a sua função de ativação é Relu;
#    * A camada de saída é do tipo densa (totalmente conectada), possui 1 único neurônio e a sua função de ativação é sigmóide.
#
#
# - O nome utilizado para essa RNA foi `model`, mas poderia ser dado qualquer outro nome.
#
#
# - O método `summary()` apresenta um resumo das principais características da rede.

# %% [markdown]
# A mesma RNA poderia também ser criada em etapas usando comandos para adicionar uma camada por vez, usando o método `add()`, como segue:

# %%
from tensorflow.keras import layers

rna = Sequential()
rna.add(layers.Dense(units=32, activation='relu', input_dim=100))
rna.add(layers.Dense(units=1, activation='sigmoid'))

rna.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,265 (12.75 KB)
#  Trainable params: 3,265 (12.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - Nesse caso o nome dado ao modelo é `rna`.
#
#
# - Nesse caso no lugar de importar somente a estrutura de modelo seqüencial, o primeiro comando importa do Keras todos os tipos de modelos.
#
#
# - O segundo comando importa do Keras todos os tipos de camadas, no lugar de somente as camadas do tipo densa, como feito anteriormente.
#
#
# - O terceiro comando cria a instância da RNA usando um modelo sequencial.
#
#
# - O quarto comando adiciona a primeira camada da RNA do tipo densa, com 32 neurônios, com função de ativação Relu, cuja entrada é um vetor linha de dimensão (1024).
#
#
# -	O quinto comando adiciona uma segunda camada tipo densa, com um único neurônio, com função de ativação sigmóide.

# %% [markdown]
# ### Dimensões dos dados de entrada
#
# A RNA precisa saber as dimensões dos dados de entrada $\to$ por essa razão a primeira camada em um modelo seqüencial precisa receber a informação sobre as dimensões dos eixos dos dados de entrada.
#
# Observa-se que somente a primeira camada precisa dessa informação $\to$ o Keras automaticamente infere as dimensões dos dados de entrada das outras camadas da RNA usando a informação dos números de neurônios de cada camada.
#
# Existem diversas formas para definir a dimensão dos dados de entrada da RNA:
#
# - Passando o argumento `input_shape` para a primeira camada. Esse argumento é uma tuple de inteiros ou simplesmente `None`, onde `None` indica que qualquer número inteiro positivo pode ser esperado;
#
# - No argumento `input_shape` o número de exemplos não é incluído $\to$ o Keras infere esse número automaticamente a partir dos dados de entrada fornecidos;
#
# - Algumas camadas 2D, tais com as densas, suportam a especificação dos dados de entrada também via argumento `input_dim`.
#
# Como exemplo, os seguintes comandos são equivalentes:
#
#     rna = models.Sequential()
#     rna.add(Dense(32,input_shape=(1024,)))
#
# ou
#
#     rna = models.Sequential()
#     rna.add(Dense(32,input_dim=1024))
#
# Se for necessário especificar um número fixo de exemplos, pode-se passar o argumento `batch_size` para a camada de entrada. Assim, por exemplo, se for usado `batch_size=32` e `input_shape=(6, 8)` para a primeira camada, será esperado como dados de entrada um tensor de dimensão (32, 6, 8).

# %% [markdown]
# O desenvolvimento de uma RNA exige muitas iterações até se obter um resultado desejável, assim, para evitar executar inúmeras vezes os mesmos comandos de configuração de uma RNA, que podem ser muitos dependendo do tamanho da RNA, pode-se criar uma função para configurar a RNA. Para isso temos, por exemplo, a seguinte função:

# %%
def  build_model(data_shape):
    rna = Sequential()
    rna.add(layers.Dense(64, activation='relu', input_shape=data_shape))
    rna.add(layers.Dense(32, activation='relu'))
    rna.add(layers.Dense(1, activation='sigmoid'))
    return rna

# %% [markdown]
# - Nesse caso o argumento `data_shape` representa a dimensão dos dados de entrada sem considerar o número de exemplos.

# %% [markdown]
# ### Visualização da RNA configurada
#
# Para visualizar a arquitetura de uma RNA que foi criada usa-se no Keras o método `summary()`, como segue:

# %%
data_shape = (1000,)
rna = build_model(data_shape)
rna.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 64)             │        64,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,177 (258.50 KB)
#  Trainable params: 66,177 (258.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - A arquitetura da RNA é apresentada em uma tabela, cujo conteúdo é o seguinte:
#
#   * Primeira coluna fornece os tipos de camadas da rede e numera as camadas;
#   * Segunda coluna apresenta o número de neurônios da camada;
#   * Terceira coluna apresenta o número de parâmetros da camada $\to$ <span style="color:red"> **como calcular esses números?**</span>
#
# <br>
#
# É importante visualizar a arquitetura da RNA porque qualquer mensagem de erro na sua compilação ou no treinamento, referência a camada pelo seu número, que pode ser obtido pelo método `summary()`.
#
# Outra forma de visualizar uma RNA no Keras é fazer um gráfico da mesma usando a função `plot_model`, como segue:

# %%
from tensorflow.keras.utils import plot_model

plot_model(rna, show_shapes=True, to_file='rna.jpg', show_layer_activations=True)

# %% [markdown]
# - Esse código gera um gráfico da `rna` com o diagrama das conexões da rna. Se quiser pode-se também salvar o gráfico em um arquivo usando o argumento `to_file='nome.png'` na função `plot_model()`.
#
#
# - Se você estiver executando o seu código no mesmo diretório onde estão os seus arquivos, então, não precisa incluir o diretório, basta incluir o nome do arquivo que ele será salvo no mesmo diretório onde está o seu notebook.
#
#
# - Antes de usar a função `plot_model` é necessário importá-la do Keras e também a biblioteca pydot do Python, que fornece funções para processar gráficos.

# %% [markdown]
# ## 6. Compilação
#
#
# A geração da RNA é realizada na etapa de compilação, onde é escolhida a função de custo, uma métrica para avaliação da RNA e configurado o método de treinamento.
#
# Um exemplo simples de compilação de uma RNA é o seguinte:

# %%
rna.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# - O primeiro comando importa do Keras os otimizadores.
#
#
# - O segundo comando gera e compila a RNA definindo o seguinte:
#
#   * Método de otimização$\to$ gradiente descendente;
#   * Função de custo $\to$ função logística, também chamada de entropia cruzada binária;
#   * Métrica $\to$ exatidão (veremos isso com detalhes nas próximas aulas).
#
#
# - A compilação de uma RNA exige escolher inúmeros hiperparâmetros para o método de otimização calcular os parâmetros da RNA $\to$ nesse exemplo usamos valores padrão para esses hiperparâmetros.
#
# <br>
#
# O Keras usa como princípio tornar a coisas simples, mas ao mesmo tempo permite ao usuário controlar tudo o que for necessário $\to$ se precisarmos e quisermos podemos configurar completamente o otimizador. Ver mais detalhes em https://www.tensorflow.org/api_docs/python/tf/keras/optimizers.
#
#
# Para definir os parâmetros do otimizador podemos realizar a compilação, por exemplo, com os seguintes comandos:

# %%
from tensorflow.keras import optimizers

sgd = optimizers.SGD(learning_rate=0.02)
rna.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# - A única diferença desse exemplo para o anterior é que definimos a taxa de aprendizado como sendo igual a 0,02.
#
#
# - Existem muitos outros hiperparâmetros que podemos definir para o otimizador, veremos alguns desses posteriormente.
#
# <br>
#
# Podemos incluir mais de uma métrica. Por exemplo, para calcular além da exatidão o erro absoluto médio, o método `compile` é usado da seguinte forma:

# %%
rna.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy', 'mae'])

# %% [markdown]
# - Observe que o termo `mae` no código acima representa as primeiras letras do termo em inglês “mean absolute error”.

# %% [markdown]
# ##  7. Treinamento
#
# O treinamento de uma RNA é realizado com o método `fit()` $\to$ para treinar uma RNA usando 10 épocas o comando usado é o seguinte:
#
#     rna.fit(x_train, y_train, epochs=10, verbose=2)
#
# - O método `fit` realiza o treinamento da RNA com os exemplos de treinamento compostos pelos dados de entrada, `x_train`, e os dados de saída, `y_train`.
#
#
# - `epochs=10` significa que são usadas 10 épocas de treinamento.
#
#
# - `verbose=2` significa que após cada época são apresentados os valores da função de custo e da métrica.
#
#
# - Existem diversos argumentos para o método `fit`, que veremos posteriormente.
#
#
# - Todas as opções para o método `fit` podem ser vistas com detalhes na documentação do Keras.

# %% [markdown]
# ### 7.1 Salvar o processo de treinamento
#
# Salvar o processo de treinamento permite fazer gráficos da função de custo e da métrica, permitindo uma análise mais detalhada do processo. Para isso usamos:
#
#     historia = rna.fit(x_train, y_train, epochs=10)
#
# - Nesse comando de treinamento os valores da função de custo e da métrica em função das épocas são salvos no objeto `historia`.
#
# O objeto `historia` contém um dicionário com os valores da função de custo e das métricas em função do número de épocas, que podem ser acessadas usando o seguinte comenado:
#
#     history_dict = historia.history
#     history_dict.keys()
#
#  - O comando `history_dict.keys` apresenta o conteúdo do dicionário salvo durante o treinamento.

# %% [markdown]
# ### 7.2 Exemplo
#
# Nesse exemplo é mostrado como realizar a configuração, a compilação e o treinamento de uma RNA usando o Keras para um problema de classificação binária de pontos no plano.
#
#
# #### Carregar dados de entrada
#
# No código da célula abaixo é importado o conjunto de dados de pontos no plano com padrão "noise_moons" da biblioteca Sklearn.

# %%
# Importa conjunto de dados da bblioteca Sklearn e bolbioteca Matplotlib
import sklearn.datasets
import matplotlib.pyplot as plt

# Define número de exemplos e chama função para gerar os dados
m = 1000
data = sklearn.datasets.make_moons(n_samples=m, noise=.3)

# Recupera dados de entrada e de saída do conjunto de dados
X, Y = data

# Separa dados em conjunsto de treinamento e teste
X_train = X[:800,:]
Y_train = Y[:800]
X_teste = X[800:,:]
Y_teste = Y[800:]

# Determina dimensão dos dados
shape_X_train = X_train.shape
shape_Y_train = Y_train.shape
shape_X_teste = X_teste.shape
shape_Y_teste = Y_teste.shape

print ('A dimensão de X_train é: ' + str(shape_X_train))
print ('A dimensão de Y_train é: ' + str(shape_Y_train))
print ('A dimensão de X_teste é: ' + str(shape_X_teste))
print ('A dimensão de Y_teste é: ' + str(shape_Y_teste))

# Visualização dos dados
plt.figure(figsize=(6, 4.5))
plt.scatter(X[:, 0], X[:, 1], c=Y.ravel(), s=40, cmap=plt.cm.Spectral)
plt.show()
# Out:
# A dimensão de X_train é: (800, 2)
# A dimensão de Y_train é: (800,)
# A dimensão de X_teste é: (200, 2)
# A dimensão de Y_teste é: (200,)

# %%
print('Saida:', Y_train[:10])
print("Entrada", X_train[:10])
# Out:
# Saida: [1 0 0 0 0 1 0 1 1 0]
# Entrada [[-0.03110066  0.30620849]
#  [-0.40159508  0.68432363]
#  [-0.12768001  0.68357468]
#  [ 0.23348161  0.87108304]
#  [ 0.26529683  0.83793748]
#  [ 1.42621588 -0.47588349]
#  [ 0.6683731   0.80889952]
#  [ 1.1240909  -0.3765926 ]
#  [-0.08724158 -0.09277623]
#  [-0.00849991  0.93943278]]

# %% [markdown]
# - Note que são usados 800 exemplos de treinamento e 200 exemplos de teste;
#
#
# - O ruído nos dados apresenta um desvio padrão de 0.3.

# %% [markdown]
# #### Configuração da RNA
#
# Para resolver esse problema é usada uma RNA sequencial de 3 camadas com a seguinte configuração:
#
# - Uma camada intermediária com 10 neurônios e função de ativação ReLu;
# - Uma camada intermediária com 4 neurônios e função de ativação ReLu;
# - Uma camada de saída com 1 neurônio e função de ativação sigmoide.

# %% [markdown]
# - Observa-se que essa RNA possui somente 79 parâmetros, o que é relativamente pouco.
#
#
# #### Compilação da RNA
#
# Para compliar essa RNA são utilizados os seguintes parâmetros:
#
# - Método de otimização: gradiente descendente;
# - Taxa de aprendizado: `lr = 0.5`;
# - Função de custo: função logística (`binary_crossentropy´);
# - Métrica: exatidão (`accuracy`).

# %% [markdown]
# #### Treinamento da RNA
#
# O processo de treinamento da RNA é realizado usando os seguintes parâmetros:
#
# - número de épocas: `epochs=1000`;
# - `verbose=0` para não mostrar nenhuma saída, pois o processo de treinamento é salvo no dicionário `historia`.

# %% [markdown]
# #### Visualizaçao do resultado do treinamento
#
# O objeto historia contém um dicionário com os valores da função de custo e das métricas em função do número de épocas, que podem ser acessadas fazendo-se:

# %%
historia_dict = historia.history
historia_dict.keys()

# %% [markdown]
# - O comando `historia_dict.keys` apresenta o conteúdo do dicionário salvo durante o treinamento, que no caso são: função de custo (`loss`) e a métrica exatidão (`accuracy`).
#
#
# Após recuperar e verificar o conteúdo do objeto history, podemos colocar os valores da função de custo e das métricas em vetores, usando os seguintes comandos:

# %%
# Salva custo,métrica e épocas em vetores
custo = historia_dict['loss']
exatidao = historia_dict['accuracy']

# Cria vetor de épocas
epocas = range(1, len(custo) + 1)

# %% [markdown]
# Os gráficos da função de custo e da métrica em função das épocas podem ser realizados usando as funções da bilbioteca Matplotlib da seguinte forma:

# %%
# Gráfico do custo
plt.plot(epocas, custo, 'b')
plt.title('Valor da função de custo')
plt.xlabel('Épocas')
plt.ylabel('Custo')
plt.show()

# Gráfico da exatidão
plt.plot(epocas, exatidao, 'r')
plt.title('Valor da exatidão')
plt.xlabel('Épocas')
plt.ylabel('Exatidão')
plt.show()

# %% [markdown]
# - No comando plot o símbolo `b` significa que queremos uma curva contínua azul (b de “blue”);
#
#
# - Observe que o gráfico somente é mostrado após o comando `plt.show()`.

# %% [markdown]
# ## 8. Avaliação do desempenho da RNA
#
# Após treinar a RNA é importante avaliar o seu desempenho com dados que não foram utilizados no treinamento.
#
# A avaliação da RNA com o conjunto de dados de teste pode ser feita usando o método evaluate da seguinte forma:

# %% [markdown]
# - A saída do método evaluate é uma lista com os valores da função de custo e da métrica para os exemplos do conjunto de teste.
#
#
# A avaliação da RNA também pode ser realizada calculando-se as saídas previstas dos exemplos do conjunto de teste usando o método `predict`, como segue:

# %% [markdown]
# - A saída do método `predict` é uma lista com os valores das saídas calculadas para cada exemplo do conjunto de teste.
#
#
# Para um problema de classificação binária, a última camada da RNA é uma função sigmoide cujas as saídas calculadas são valores entre 0 e 1.
#
# Para determinar a classe prevista podemos simplesmente adotar, como feito no código anterior que:
#
#     Se y_prev >= 0,5, então, classe = 1;
#     Se y_prev < 0.5, então, classe = 0;
#
# Pode-se fazer um gráfico mostrando as classes reais e as previstas pela RNA $\to$  esse gráfico permite uma boa visualização dos resultados.

# %%
# Gráfico das classes reais e previstas
plt.figure(figsize=(16, 6))
plt.plot(Y_teste, 'ro', label='Classes reais')
plt.plot(classes, 'bo', label='Classes previstas')
plt.title('Classes reais e previstas')
plt.xlabel('Exemplos')
plt.ylabel('Classes')
plt.legend()
plt.show

# %% [markdown]
# - Alguns detalhes desses comandos são os seguintes:
#
#    * Nos comandos `plot` os símbolos `ro` e `bo` significam que queremos marcar essas curvas com círculos vermelhos e azuis respectivamente;
#
#    * Observe que podemos colocar vários comandos `plot` em seqüência para fazermos várias curvas no mesmo gráfico e o gráfico somente é mostrado após o comando `show`;
#
#    * Para incluir uma legenda incluímos o atributo `label` nos comandos `plot` e após esses comandos incluímos o comando `legend()` para mostrar a legenda no gráfico.

# %% [markdown]
# ## 9. Salvar uma RNA treinada
#
#
# Após desenvolvermos uma RNA podemos salvá-la em um arquivo para podemos utilizá-la posteriormente.
#
# Podemos salvar somente a arquitetura da rede, ou somente seus parâmetros, ou ainda a arquitetura e seus parâmetros.
#
# ### Salvar uma RNA completa
#
# Para salvar uma RNA desenvolvida com o Keras usamos o método `save(file_path_and_name)` $\to$ nesse caso a RNA é salva em um arquivo no formato hdf5 que contém:
#
# - A arquitetura da RNA;
# - Os parâmetros da RNA;
# - Os parâmetros do otimizador usado para treinar a RNA;
# - O estado do otimizador para permitir continuar o treinamento exatamente de onde parou.
#
# Tendo uma RNA salva em um arquivo do formato HDF5 podemos usar o método `load_model(file_path_and_name)` para restabelecer a RNA da mesma forma que era quando foi salva.
#
# Um exemplo de uso desses dois métodos é o seguinte:

# %% [markdown]
# ### Apagar e carregar uma RNA
#
# Para apagar uma RNA da memória usa-se o método `del`.
#
# Para carregar uma RNA salva em um arquivo usa-se o método `load_model()`. Antes de usar esse método tem que carregar o método `load_model` da classe `tensorflow.keras.models`.

# %% [markdown]
# - Para esses métodos funcionarem é necessário que a biblioteca h5py do Python esteja instalada em seu computador.
#
#
# - Se quiser salvara RNA no mesmo diretório onde está o notebook não precisa incluir o nome do diretório antes do arquivo que deseja salvar a RNA.

# %% [markdown]
# ### Salvar os parâmetros de uma RNA
#
# Se desejarmos salvar somente os parâmetros de uma RNA usamos o método `save_weigths(file_path_and_name)` da seguinte forma:

# %% [markdown]
# Para carregar esses parâmetros em outra RNA (rna2) usa-se o método `load_weights`da seguinte forma:

# %% [markdown]
# - A mensagem de erro gerada é porque a `rna2` não existe.
#
#
# Para carregar parâmetros em uma RNA, deve-se ter uma rede criada com a mesma arquitetura da rede que gerou os parâmetros.
#
# No código da célula baixo é criada a `rna2` igual à `rna` para poder receber os seus parâmetros.

# %% [markdown]
# Existem muitas situações onde queremos desenvolver uma nova RNA (`rna_nova`) utilizando como base outra RNA (`rna_base`) já treinada. Porém, queremos aproveitar somente os parâmetros de algumas camadas da `rna_base` na `rna_nova` $\to$ isso é possível de fazer usando os métodos `save_weights()` e `load_weights()` com pequenas alterações (veremos isso posteriormente).
